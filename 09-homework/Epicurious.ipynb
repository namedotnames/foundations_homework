# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
response = requests.get('https://www.epicurious.com/search/cucumbers')
doc = BeautifulSoup(response.text)

# %%
rows = []

for num in range(1, 11):
    url = f'https://www.epicurious.com/search/cucumbers?page={num}'
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    contents = doc.find_all(class_ = re.compile('.*-content-card'))
    print('Scraping', url)
    for content in contents:
        row = {}
        row['Tag'] = content.find(class_ = 'summary').strong.text
        row['Title'] = content.h4.text
        try:
            row['Summary'] = content.find(class_ = 'dek').text
        except:
            pass
        try:
            row['Rating'] = content.find(itemprop = 'ratingValue').text
        except:
            pass
        try:
            row['Make_Again_Pct'] = content.find(class_ = 'make-again-percentage').text
        except:
            pass
        row['Url'] = content.find(class_ = 'hed').a['href']
        rows.append(row)
# Out:
# Scraping https://www.epicurious.com/search/cucumbers?page=1
# Scraping https://www.epicurious.com/search/cucumbers?page=2
# Scraping https://www.epicurious.com/search/cucumbers?page=3
# Scraping https://www.epicurious.com/search/cucumbers?page=4
# Scraping https://www.epicurious.com/search/cucumbers?page=5
# Scraping https://www.epicurious.com/search/cucumbers?page=6
# Scraping https://www.epicurious.com/search/cucumbers?page=7
# Scraping https://www.epicurious.com/search/cucumbers?page=8
# Scraping https://www.epicurious.com/search/cucumbers?page=9
# Scraping https://www.epicurious.com/search/cucumbers?page=10

# %%
df = pd.DataFrame(rows)
df = df[['Title', 'Tag', 'Summary', 'Url', 'Rating', 'Make_Again_Pct']]
df.head()
# Out:
#                                                Title     Tag  \
# 0                    Spicy Lightly Pickled Cucumbers  recipe
# 1                    Cucumbers with Ajo Blanco Sauce  recipe
# 2   Cold Beef Tenderloin with Tomatoes and Cucumbers  recipe
# 3  Fried Fish Sandwiches with Cucumbers and Tarta...  recipe
# 4            Grain Salad with Tomatoes and Cucumbers  recipe
#
#                                              Summary  \
# 0  These quick pickles have just the right amount...
# 1  Think of this as an all-purpose garlic sauce. ...
# 2  Beef tenderloin is precious enough to baby on ...
# 3  Take your cast-iron pan to the grill for this ...
# 4  We call for semi-pearled grains because they c...
#
#                                                  Url Rating Make_Again_Pct
# 0  /recipes/food/views/spicy-lightly-pickled-cucu...      4           100%
# 1  /recipes/food/views/cucumbers-with-ajo-blanco-...      4           100%
# 2  /recipes/food/views/cold-beef-tenderloin-with-...      2             0%
# 3  /recipes/food/views/fried-fish-sandwiches-with...      3           100%
# 4  /recipes/food/views/farro-spelt-grain-salad-wi...      3           100%

# %%
df.to_csv('Epicurious_cucumbers.csv', index = False)

# %% [markdown]
# Part 2

# %%
df = pd.read_csv('Epicurious_cucumbers.csv')

# %%
df = df[df.Tag == 'recipe']

# %%
def scrap_page(food):
    row = {}
    url = f"https://www.epicurious.com/{food['Url']}"
    print('Scraping', url)
    response = requests.get(url)
    contents = BeautifulSoup(response.text)
    row['Title'] = contents.find(class_ = 'title-source').h1.text.strip()
    row['Ingredients'] = list(map(lambda x: x.text, contents.find('ul', class_ = 'ingredients').find_all(class_ = 'ingredient')))
    row['Direction'] = list(map(lambda x: x.text.strip(), contents.find(class_ = 'preparation-group').find_all(class_ = 'preparation-step')))
    row['Tags'] = list(map(lambda x: x.text, contents.find(class_ = 'menus-tags content').find(class_ = 'tags').find_all('dt')))
    print(row)
    return pd.Series(row)

# %%
scraped_df = df.apply(scrap_page, axis = 1)
# Out:
# Scraping https://www.epicurious.com//recipes/food/views/spicy-lightly-pickled-cucumbers
# {'Title': 'Spicy Lightly Pickled Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/spicy-lightly-pickled-cucumbers
# {'Title': 'Spicy Lightly Pickled Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/cucumbers-with-ajo-blanco-sauce
# {'Title': 'Cucumbers with Ajo Blanco Sauce', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/cold-beef-tenderloin-with-tomatoes-and-cucumbers
# {'Title': 'Cold Beef Tenderloin with Tomatoes and Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/fried-fish-sandwiches-with-cucumbers-and-tartar-sauce
# {'Title': 'Fried Fish Sandwiches with Cucumbers and Tartar Sauce', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/farro-spelt-grain-salad-with-tomatoes-and-cucumbers
# {'Title': 'Grain Salad with Tomatoes and Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/grilled-charred-cabbage-with-goat-cheese-raita-and-cucumbers
# {'Title': 'Charred Cabbage with Goat Cheese Raita and Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/cucumber-seaweed-salad
# {'Title': 'Cucumber-Seaweed Salad', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/pineapple-shrimp-noodle-bowls
# {'Title': 'Pineapple Shrimp Noodle Bowls', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/sambal-shrimp-lettuce-wraps
# {'Title': 'Sambal Shrimp Lettuce Wraps', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/smashed-cucumber-salad-with-lemon-and-celery-salt
# {'Title': 'Smashed Cucumber Salad with Lemon and Celery Salt', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/thai-style-squid-and-cucumber-salad
# {'Title': 'Thai-Style Squid and Cucumber Salad', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/spicy-grilled-chicken-with-crunchy-fennel-salad
# {'Title': 'Spicy Grilled Chicken with Crunchy Fennel Salad', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/grilled-salmon-with-meyer-lemons-and-creamy-cucumber-salad
# {'Title': 'Grilled Salmon with Meyer Lemons and Creamy Cucumber Salad', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/smashed-cucumber-salad-with-hot-vinegar
# {'Title': 'Smashed Cucumber Salad with Hot Vinegar', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/sams-spring-cucumber-radish-fattoush-salad
# {'Title': "Sam's Spring Fattoush Salad", 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/skirt-steak-with-spicy-coconut-dressing
# {'Title': 'Skirt Steak with Spicy Coconut Dressing', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/mango-toast-with-hazelnut-pepita-butter
# {'Title': 'Mango Toast with Hazelnut-Pepita Butter', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/quick-pickled-charred-grilled-vegetables
# {'Title': 'Quick-Pickled Charred Vegetables', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/green-beans-and-cucumbers-with-miso-dressing
# {'Title': 'Green Beans and Cucumbers with Miso Dressing', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/fish-milanese-with-cucumber-ceviche
# {'Title': 'Fish Milanese with Cucumber Ceviche', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/thai-style-pineapple-coconut-rice
# {'Title': 'Thai-Style Pineapple-Coconut Rice', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/rice-noodles-with-peanut-sauce-chicken-and-snap-peas
# {'Title': 'Rice Noodles with Peanut Sauce, Chicken, and Snap Peas', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/thai-beef-salad
# {'Title': 'Thai Beef Salad', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/smashed-cucumbers-and-radishes-in-yogurt-sauce
# {'Title': 'Smashed Cucumbers and Radishes in Yogurt Sauce', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/herby-chicken-kofta-meatballs
# {'Title': 'Herby Chicken Kofta Meatballs', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/teriyaki-steak-skewers-with-asian-style-greens
# {'Title': 'Teriyaki Steak Skewers with Asian-Style Greens', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/yogurt-with-raisins-cucumber-and-walnuts
# {'Title': 'Yogurt with Raisins, Cucumber, and Walnuts', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/fast-favorite-garlic-dill-pickles-230707
# {'Title': 'Fast Favorite Garlic Dill Pickles', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/kale-and-cucumber-salad-with-roasted-ginger-dressing
# {'Title': 'Kale and Cucumber Salad with Roasted Ginger Dressing', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/chilled-beet-soup-with-buttermilk-cucumbers-and-dill-chlodnik
# {'Title': 'Chilled Beet Soup with Buttermilk, Cucumbers, and Dill (Chlodnik)', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/flatbread-with-fava-beans-cucumbers-and-burrata
# {'Title': 'Flatbread with Fava Beans, Cucumbers, and Burrata', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/moroccan-skirt-steak-salad-with-chermoula
# {'Title': 'Moroccan Skirt Steak Salad With Chermoula', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/cucumber-and-raisin-relish-with-mustard-seeds
# {'Title': 'Cucumber and Raisin Relish with Mustard Seeds', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/fresh-dill-cucumbers-with-lemon
# {'Title': 'Fresh Dill Cucumbers with Lemon', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/crispy-pork-lettuce-wraps-with-spicy-cucumbers-56390119
# {'Title': 'Crispy Pork Lettuce Wraps With Spicy Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/miso-cured-black-cod-with-chilled-cucumbers-56389995
# {'Title': 'Miso-Cured Black Cod with Chilled Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/cold-asian-noodle-salad-with-chicken-and-cucumbers-56389799
# {'Title': 'Cold Asian Noodle Salad with Chicken and Cucumbers', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/cucumbers-with-scallions-and-chili-oil-56389645
# {'Title': 'Cucumbers with Scallions and Chili Oil', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/strawberry-cucumber-salad-with-lemon-cream-56389861
# {'Title': 'Strawberry-Cucumber Salad with Lemon Cream', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/ginger-dill-pickles-56389773
# {'Title': 'Ginger-Dill Pickles', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/sweet-and-sour-pickles-56389775
# {'Title': 'Sweet and Sour Pickles', 'Ingredients': [], 'Direction': [], 'Tags': []}
# Scraping https://www.epicurious.com//recipes/food/views/charred-romaine-greek-salad-with-quinoa-crusted-feta-56389585
# {'Title': 'Charred Romaine Greek Salad With Quinoa-Crusted Feta', 'Ingredients': [], 'Direction': [], 'Tags': []}

# %%
scraped_df.head()
# Out:
#                                                Title Ingredients Direction  \
# 0                    Spicy Lightly Pickled Cucumbers          []        []
# 1                    Cucumbers with Ajo Blanco Sauce          []        []
# 2   Cold Beef Tenderloin with Tomatoes and Cucumbers          []        []
# 3  Fried Fish Sandwiches with Cucumbers and Tarta...          []        []
# 4            Grain Salad with Tomatoes and Cucumbers          []        []
#
#   Tags
# 0   []
# 1   []
# 2   []
# 3   []
# 4   []

# %%
merged_df = df.join(scraped_df, rsuffix = '_scraped').drop(columns = 'Title_scraped')
merged_df.head()
# Out:
#                                                Title     Tag  \
# 0                    Spicy Lightly Pickled Cucumbers  recipe
# 1                    Cucumbers with Ajo Blanco Sauce  recipe
# 2   Cold Beef Tenderloin with Tomatoes and Cucumbers  recipe
# 3  Fried Fish Sandwiches with Cucumbers and Tarta...  recipe
# 4            Grain Salad with Tomatoes and Cucumbers  recipe
#
#                                              Summary  \
# 0  These quick pickles have just the right amount...
# 1  Think of this as an all-purpose garlic sauce. ...
# 2  Beef tenderloin is precious enough to baby on ...
# 3  Take your cast-iron pan to the grill for this ...
# 4  We call for semi-pearled grains because they c...
#
#                                                  Url  Rating Make_Again_Pct  \
# 0  /recipes/food/views/spicy-lightly-pickled-cucu...     4.0           100%
# 1  /recipes/food/views/cucumbers-with-ajo-blanco-...     4.0           100%
# 2  /recipes/food/views/cold-beef-tenderloin-with-...     2.0             0%
# 3  /recipes/food/views/fried-fish-sandwiches-with...     3.0           100%
# 4  /recipes/food/views/farro-spelt-grain-salad-wi...     3.0           100%
#
#   Ingredients Direction Tags
# 0          []        []   []
# 1          []        []   []
# 2          []        []   []
# 3          []        []   []
# 4          []        []   []

# %%
merged_df.to_csv('Epicurious_cucumbers.csv', index = False)
