# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
df = pd.DataFrame(rows)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b0ca3ebffeb2> in <module>
# ----> 1 df = pd.DataFrame(rows)
#       2 df
#
# NameError: name 'rows' is not defined

# %%
all_books = doc.find_all('tr', itemtype="http://schema.org/Book")

rows = []

for book in all_books:
    
    row = {}
    
    row['rank'] = book.find(class_='number').text.strip()
    row['title'] = book.find(class_='bookTitle').text.strip()
    row['author'] = book.find(class_='authorName').text.strip()
    row['score'] = book.find(onclick="Lightbox.showBoxByID('score_explanation', 300); return false;").text.strip()
    row['votes'] =  book.find('a', href="#").find_next_sibling('a').text.strip()
    row['rating'] = book.find(class_='minirating').text.strip()
  

    rows.append(row)

rows
# Out:
# [{'rank': '1',
#   'title': "The Handmaid's Tale",
#   'author': 'Margaret Atwood',
#   'score': 'score: 30,733',
#   'votes': '314 people voted',
#   'rating': '4.09 avg rating — 1,102,749 ratings'},
#  {'rank': '2',
#   'title': 'The Hunger Games (The Hunger Games, #1)',
#   'author': 'Suzanne Collins',
#   'score': 'score: 28,553',
#   'votes': '292 people voted',
#   'rating': '4.33 avg rating — 5,742,283 ratings'},
#  {'rank': '3',
#   'title': 'Frankenstein',
#   'author': 'Mary Wollstonecraft Shelley',
#   'score': 'score: 21,909',
#   'votes': '224 people voted',
#   'rating': '3.78 avg rating — 1,023,563 ratings'},
#  {'rank': '4',
#   'title': 'A Wrinkle in Time (Time Quintet, #1)',
#   'author': "Madeleine L'Engle",
#   'score': 'score: 18,720',
#   'votes': '196 people voted',
#   'rating': '4.01 avg rating — 903,541 ratings'},
#  {'rank': '5',
#   'title': 'The Left Hand of Darkness (Hainish Cycle #4)',
#   'author': 'Ursula K. Le Guin',
#   'score': 'score: 17,920',
#   'votes': '184 people voted',
#   'rating': '4.06 avg rating — 98,810 ratings'},
#  {'rank': '6',
#   'title': 'Divergent (Divergent, #1)',
#   'author': 'Veronica Roth',
#   'score': 'score: 13,326',
#   'votes': '138 people voted',
#   'rating': '4.21 avg rating — 2,603,019 ratings'},
#  {'rank': '7',
#   'title': 'Catching Fire (The Hunger Games, #2)',
#   'author': 'Suzanne Collins',
#   'score': 'score: 12,749',
#   'votes': '133 people voted',
#   'rating': '4.29 avg rating — 2,200,866 ratings'},
#  {'rank': '8',
#   'title': 'The Giver (The Giver, #1)',
#   'author': 'Lois Lowry',
#   'score': 'score: 12,399',
#   'votes': '129 people voted',
#   'rating': '4.12 avg rating — 1,535,313 ratings'},
#  {'rank': '9',
#   'title': 'Kindred',
#   'author': 'Octavia E. Butler',
#   'score': 'score: 11,070',
#   'votes': '116 people voted',
#   'rating': '4.23 avg rating — 72,354 ratings'},
#  {'rank': '10',
#   'title': 'The Dispossessed (Hainish Cycle #6)',
#   'author': 'Ursula K. Le Guin',
#   'score': 'score: 10,731',
#   'votes': '112 people voted',
#   'rating': '4.21 avg rating — 71,652 ratings'},
#  {'rank': '11',
#   'title': 'Oryx and Crake (MaddAddam, #1)',
#   'author': 'Margaret Atwood',
#   'score': 'score: 10,117',
#   'votes': '107 people voted',
#   'rating': '4.01 avg rating — 197,821 ratings'},
#  {'rank': '12',
#   'title': 'Mockingjay (The Hunger Games, #3)',
#   'author': 'Suzanne Collins',
#   'score': 'score: 9,807',
#   'votes': '104 people voted',
#   'rating': '4.03 avg rating — 2,072,116 ratings'},
#  {'rank': '13',
#   'title': "The Time Traveler's Wife",
#   'author': 'Audrey Niffenegger',
#   'score': 'score: 9,193',
#   'votes': '98 people voted',
#   'rating': '3.96 avg rating — 1,446,821 ratings'},
#  {'rank': '14',
#   'title': 'Doomsday Book (Oxford Time Travel, #1)',
#   'author': 'Connie Willis',
#   'score': 'score: 8,935',
#   'votes': '96 people voted',
#   'rating': '4.03 avg rating — 43,253 ratings'},
#  {'rank': '15',
#   'title': 'The Lathe of Heaven',
#   'author': 'Ursula K. Le Guin',
#   'score': 'score: 7,775',
#   'votes': '84 people voted',
#   'rating': '4.11 avg rating — 44,001 ratings'},
#  {'rank': '16',
#   'title': 'Ancillary Justice (Imperial Radch #1)',
#   'author': 'Ann Leckie',
#   'score': 'score: 7,336',
#   'votes': '81 people voted',
#   'rating': '3.98 avg rating — 66,220 ratings'},
#  {'rank': '17',
#   'title': 'Shards of Honour  (Vorkosigan Saga, #1)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 7,017',
#   'votes': '75 people voted',
#   'rating': '4.11 avg rating — 25,885 ratings'},
#  {'rank': '18',
#   'title': 'To Say Nothing of the Dog (Oxford Time Travel, #2)',
#   'author': 'Connie Willis',
#   'score': 'score: 6,890',
#   'votes': '74 people voted',
#   'rating': '4.13 avg rating — 29,644 ratings'},
#  {'rank': '19',
#   'title': 'The Sparrow (The Sparrow, #1)',
#   'author': 'Mary Doria Russell',
#   'score': 'score: 6,873',
#   'votes': '72 people voted',
#   'rating': '4.17 avg rating — 52,755 ratings'},
#  {'rank': '20',
#   'title': 'Dragonflight (Dragonriders of Pern, #1)',
#   'author': 'Anne McCaffrey',
#   'score': 'score: 6,802',
#   'votes': '74 people voted',
#   'rating': '4.10 avg rating — 116,164 ratings'},
#  {'rank': '21',
#   'title': 'Parable of the Sower (Earthseed, #1)',
#   'author': 'Octavia E. Butler',
#   'score': 'score: 6,653',
#   'votes': '71 people voted',
#   'rating': '4.16 avg rating — 42,254 ratings'},
#  {'rank': '22',
#   'title': "The Warrior's Apprentice (Vorkosigan Saga, #2)",
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 6,087',
#   'votes': '65 people voted',
#   'rating': '4.29 avg rating — 20,959 ratings'},
#  {'rank': '23',
#   'title': 'Barrayar (Vorkosigan Saga, #7)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 5,623',
#   'votes': '60 people voted',
#   'rating': '4.31 avg rating — 22,112 ratings'},
#  {'rank': '24',
#   'title': 'The Host (The Host, #1)',
#   'author': 'Stephenie Meyer',
#   'score': 'score: 5,274',
#   'votes': '56 people voted',
#   'rating': '3.84 avg rating — 829,025 ratings'},
#  {'rank': '25',
#   'title': 'Insurgent (Divergent, #2)',
#   'author': 'Veronica Roth',
#   'score': 'score: 4,899',
#   'votes': '54 people voted',
#   'rating': '4.05 avg rating — 1,045,881 ratings'},
#  {'rank': '26',
#   'title': 'Memory (Vorkosigan Saga, #10)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 4,682',
#   'votes': '51 people voted',
#   'rating': '4.45 avg rating — 13,950 ratings'},
#  {'rank': '27',
#   'title': 'The Children of Men',
#   'author': 'P.D. James',
#   'score': 'score: 4,484',
#   'votes': '49 people voted',
#   'rating': '3.68 avg rating — 36,107 ratings'},
#  {'rank': '28',
#   'title': 'Starshine: Aurora Rising Book One (Aurora Rhapsody, #1)',
#   'author': 'G.S. Jennsen',
#   'score': 'score: 4,394',
#   'votes': '45 people voted',
#   'rating': '3.91 avg rating — 2,146 ratings'},
#  {'rank': '29',
#   'title': 'The Year of the Flood  (MaddAddam, #2)',
#   'author': 'Margaret Atwood',
#   'score': 'score: 4,343',
#   'votes': '47 people voted',
#   'rating': '4.06 avg rating — 92,237 ratings'},
#  {'rank': '30',
#   'title': 'Crystal Singer (Crystal Singer, #1)',
#   'author': 'Anne McCaffrey',
#   'score': 'score: 4,235',
#   'votes': '47 people voted',
#   'rating': '4.09 avg rating — 17,775 ratings'},
#  {'rank': '31',
#   'title': 'Mirror Dance (Vorkosigan Saga, #8)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 4,120',
#   'votes': '47 people voted',
#   'rating': '4.33 avg rating — 17,331 ratings'},
#  {'rank': '32',
#   'title': "Lilith's Brood (Xenogenesis, #1-3)",
#   'author': 'Octavia E. Butler',
#   'score': 'score: 4,108',
#   'votes': '47 people voted',
#   'rating': '4.33 avg rating — 12,571 ratings'},
#  {'rank': '33',
#   'title': 'The Vor Game (Vorkosigan Saga, #6)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 3,895',
#   'votes': '46 people voted',
#   'rating': '4.28 avg rating — 18,977 ratings'},
#  {'rank': '34',
#   'title': 'Wild Seed (Patternmaster, #1)',
#   'author': 'Octavia E. Butler',
#   'score': 'score: 3,842',
#   'votes': '43 people voted',
#   'rating': '4.21 avg rating — 14,437 ratings'},
#  {'rank': '35',
#   'title': 'A Wind in the Door (Time Quintet, #2)',
#   'author': "Madeleine L'Engle",
#   'score': 'score: 3,700',
#   'votes': '42 people voted',
#   'rating': '4.04 avg rating — 106,044 ratings'},
#  {'rank': '36',
#   'title': 'A Civil Campaign (Vorkosigan Saga, #12)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 3,683',
#   'votes': '43 people voted',
#   'rating': '4.43 avg rating — 14,496 ratings'},
#  {'rank': '37',
#   'title': 'Brothers in Arms (Vorkosigan Saga, #5)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 3,653',
#   'votes': '43 people voted',
#   'rating': '4.21 avg rating — 13,276 ratings'},
#  {'rank': '38',
#   'title': 'Cetaganda (Vorkosigan Saga, #9)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 3,618',
#   'votes': '43 people voted',
#   'rating': '4.17 avg rating — 14,831 ratings'},
#  {'rank': '39',
#   'title': 'The Snow Queen (The Snow Queen Cycle, #1)',
#   'author': 'Joan D. Vinge',
#   'score': 'score: 3,535',
#   'votes': '43 people voted',
#   'rating': '3.95 avg rating — 11,144 ratings'},
#  {'rank': '40',
#   'title': 'Cinder (The Lunar Chronicles, #1)',
#   'author': 'Marissa Meyer',
#   'score': 'score: 3,440',
#   'votes': '38 people voted',
#   'rating': '4.15 avg rating — 582,877 ratings'},
#  {'rank': '41',
#   'title': 'Downbelow Station (The Company Wars, #1)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 3,381',
#   'votes': '40 people voted',
#   'rating': '3.91 avg rating — 12,109 ratings'},
#  {'rank': '42',
#   'title': 'The Ship Who Sang (Brainship, #1)',
#   'author': 'Anne McCaffrey',
#   'score': 'score: 3,361',
#   'votes': '39 people voted',
#   'rating': '4.01 avg rating — 21,160 ratings'},
#  {'rank': '43',
#   'title': 'Dragon Dawn (Dinosaurian Time Travel, #1)',
#   'author': "Deborah O'Neill Cordes",
#   'score': 'score: 3,340',
#   'votes': '34 people voted',
#   'rating': '3.81 avg rating — 194 ratings'},
#  {'rank': '44',
#   'title': 'Dragonsong (Harper Hall, #1)',
#   'author': 'Anne McCaffrey',
#   'score': 'score: 3,092',
#   'votes': '36 people voted',
#   'rating': '4.25 avg rating — 43,820 ratings'},
#  {'rank': '45',
#   'title': 'Falling Free (Vorkosigan Saga, #4)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 3,054',
#   'votes': '37 people voted',
#   'rating': '3.83 avg rating — 16,015 ratings'},
#  {'rank': '46',
#   'title': 'Ethan of Athos (Vorkosigan Saga, #3)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 2,904',
#   'votes': '36 people voted',
#   'rating': '3.76 avg rating — 11,391 ratings'},
#  {'rank': '47',
#   'title': 'A Swiftly Tilting Planet (Time Quintet, #3)',
#   'author': "Madeleine L'Engle",
#   'score': 'score: 2,831',
#   'votes': '32 people voted',
#   'rating': '4.11 avg rating — 95,090 ratings'},
#  {'rank': '48',
#   'title': 'Dawn (Xenogenesis, #1)',
#   'author': 'Octavia E. Butler',
#   'score': 'score: 2,755',
#   'votes': '32 people voted',
#   'rating': '4.12 avg rating — 22,780 ratings'},
#  {'rank': '49',
#   'title': 'Komarr (Vorkosigan Saga, #11)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 2,579',
#   'votes': '31 people voted',
#   'rating': '4.30 avg rating — 12,912 ratings'},
#  {'rank': '50',
#   'title': 'Foreigner (Foreigner, #1)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 2,547',
#   'votes': '30 people voted',
#   'rating': '3.94 avg rating — 7,158 ratings'},
#  {'rank': '51',
#   'title': 'Where Late the Sweet Birds Sang',
#   'author': 'Kate Wilhelm',
#   'score': 'score: 2,535',
#   'votes': '30 people voted',
#   'rating': '3.87 avg rating — 8,282 ratings'},
#  {'rank': '52',
#   'title': 'Beggars in Spain (Sleepless, #1)',
#   'author': 'Nancy Kress',
#   'score': 'score: 2,526',
#   'votes': '30 people voted',
#   'rating': '3.94 avg rating — 6,813 ratings'},
#  {'rank': '53',
#   'title': 'Her Smoke Rose Up Forever',
#   'author': 'James Tiptree Jr.',
#   'score': 'score: 2,524',
#   'votes': '29 people voted',
#   'rating': '4.21 avg rating — 3,311 ratings'},
#  {'rank': '54',
#   'title': 'The Silver Metal Lover (Silver Metal Lover, #1)',
#   'author': 'Tanith Lee',
#   'score': 'score: 2,504',
#   'votes': '29 people voted',
#   'rating': '4.03 avg rating — 3,384 ratings'},
#  {'rank': '55',
#   'title': "Cordelia's Honor (Vorkosigan Omnibus, #1)",
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 2,498',
#   'votes': '31 people voted',
#   'rating': '4.37 avg rating — 11,641 ratings'},
#  {'rank': '56',
#   'title': 'The Pride of Chanur (Chanur #1)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 2,469',
#   'votes': '31 people voted',
#   'rating': '3.92 avg rating — 5,912 ratings'},
#  {'rank': '57',
#   'title': 'Station Eleven',
#   'author': 'Emily St. John Mandel',
#   'score': 'score: 2,450',
#   'votes': '28 people voted',
#   'rating': '4.03 avg rating — 253,847 ratings'},
#  {'rank': '58',
#   'title': 'Cyteen (Cyteen, #1-3)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 2,316',
#   'votes': '30 people voted',
#   'rating': 'really liked it 4.00 avg rating — 9,285 ratings'},
#  {'rank': '59',
#   'title': 'Borders of Infinity (Vorkosigan Saga [Publication] #5.1-5.3)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 2,306',
#   'votes': '29 people voted',
#   'rating': '4.24 avg rating — 8,712 ratings'},
#  {'rank': '60',
#   'title': 'Grass (Arbai, #1)',
#   'author': 'Sheri S. Tepper',
#   'score': 'score: 2,203',
#   'votes': '27 people voted',
#   'rating': '4.04 avg rating — 9,266 ratings'},
#  {'rank': '61',
#   'title': 'Chameleon (The Domino Project, #1)',
#   'author': 'K.T. Hanna',
#   'score': 'score: 2,199',
#   'votes': '22 people voted',
#   'rating': '4.18 avg rating — 191 ratings'},
#  {'rank': '62',
#   'title': "The Gate to Women's Country",
#   'author': 'Sheri S. Tepper',
#   'score': 'score: 2,191',
#   'votes': '27 people voted',
#   'rating': '4.05 avg rating — 11,541 ratings'},
#  {'rank': '63',
#   'title': 'The Female Man',
#   'author': 'Joanna Russ',
#   'score': 'score: 2,128',
#   'votes': '26 people voted',
#   'rating': '3.54 avg rating — 5,351 ratings'},
#  {'rank': '64',
#   'title': 'In the Garden of Iden (The Company, #1)',
#   'author': 'Kage Baker',
#   'score': 'score: 2,038',
#   'votes': '26 people voted',
#   'rating': '3.77 avg rating — 4,995 ratings'},
#  {'rank': '65',
#   'title': 'Rogue Genesis (Shimmer in the Dark, #1)',
#   'author': 'Ceri London',
#   'score': 'score: 2,013',
#   'votes': '21 people voted',
#   'rating': '4.44 avg rating — 133 ratings'},
#  {'rank': '66',
#   'title': 'Parable of the Talents (Earthseed, #2)',
#   'author': 'Octavia E. Butler',
#   'score': 'score: 2,006',
#   'votes': '25 people voted',
#   'rating': '4.24 avg rating — 17,406 ratings'},
#  {'rank': '67',
#   'title': 'The Faded Sun Trilogy (The Faded Sun #1-3)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 1,931',
#   'votes': '23 people voted',
#   'rating': '4.12 avg rating — 4,628 ratings'},
#  {'rank': '68',
#   'title': 'Diplomatic Immunity (Vorkosigan Saga, #13)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 1,914',
#   'votes': '26 people voted',
#   'rating': '4.18 avg rating — 12,109 ratings'},
#  {'rank': '69',
#   'title': "His Majesty's Dragon (Temeraire, #1)",
#   'author': 'Naomi Novik',
#   'score': 'score: 1,849',
#   'votes': '22 people voted',
#   'rating': '4.06 avg rating — 67,091 ratings'},
#  {'rank': '70',
#   'title': 'The Speed of Dark',
#   'author': 'Elizabeth Moon',
#   'score': 'score: 1,819',
#   'votes': '24 people voted',
#   'rating': 'really liked it 4.00 avg rating — 9,437 ratings'},
#  {'rank': '71',
#   'title': 'Darkover Landfall',
#   'author': 'Marion Zimmer Bradley',
#   'score': 'score: 1,748',
#   'votes': '21 people voted',
#   'rating': '3.88 avg rating — 5,952 ratings'},
#  {'rank': '72',
#   'title': 'Machinations (Machinations, #1)',
#   'author': 'Hayley Stone',
#   'score': 'score: 1,698',
#   'votes': '17 people voted',
#   'rating': '3.79 avg rating — 248 ratings'},
#  {'rank': '73',
#   'title': 'Vertigo (Aurora Rhapsody, #2)',
#   'author': 'G.S. Jennsen',
#   'score': 'score: 1,684',
#   'votes': '18 people voted',
#   'rating': '4.22 avg rating — 1,042 ratings'},
#  {'rank': '74',
#   'title': 'CryoBurn (Vorkosigan Saga, #14)',
#   'author': 'Lois McMaster Bujold',
#   'score': 'score: 1,683',
#   'votes': '24 people voted',
#   'rating': '4.06 avg rating — 11,943 ratings'},
#  {'rank': '75',
#   'title': 'Seed to Harvest (Patternmaster, #1-4)',
#   'author': 'Octavia E. Butler',
#   'score': 'score: 1,659',
#   'votes': '20 people voted',
#   'rating': '4.33 avg rating — 3,946 ratings'},
#  {'rank': '76',
#   'title': "The Wind's Twelve Quarters",
#   'author': 'Ursula K. Le Guin',
#   'score': 'score: 1,572',
#   'votes': '19 people voted',
#   'rating': '4.04 avg rating — 4,042 ratings'},
#  {'rank': '77',
#   'title': 'Remnant Population',
#   'author': 'Elizabeth Moon',
#   'score': 'score: 1,547',
#   'votes': '20 people voted',
#   'rating': '4.06 avg rating — 3,628 ratings'},
#  {'rank': '78',
#   'title': 'The Word for World is Forest',
#   'author': 'Ursula K. Le Guin',
#   'score': 'score: 1,510',
#   'votes': '20 people voted',
#   'rating': '3.95 avg rating — 12,905 ratings'},
#  {'rank': '79',
#   'title': 'Grimspace (Sirantha Jax, #1)',
#   'author': 'Ann Aguirre',
#   'score': 'score: 1,497',
#   'votes': '17 people voted',
#   'rating': '3.73 avg rating — 12,662 ratings'},
#  {'rank': '80',
#   'title': 'Ammonite',
#   'author': 'Nicola Griffith',
#   'score': 'score: 1,477',
#   'votes': '20 people voted',
#   'rating': '3.86 avg rating — 3,715 ratings'},
#  {'rank': '81',
#   'title': 'Across the Universe (Across the Universe, #1)',
#   'author': 'Beth Revis',
#   'score': 'score: 1,435',
#   'votes': '16 people voted',
#   'rating': '3.77 avg rating — 107,422 ratings'},
#  {'rank': '82',
#   'title': 'Inheritor (Foreigner, #3)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 1,392',
#   'votes': '18 people voted',
#   'rating': '4.19 avg rating — 3,610 ratings'},
#  {'rank': '83',
#   'title': 'The V Girl',
#   'author': 'Mya Robarts',
#   'score': 'score: 1,380',
#   'votes': '15 people voted',
#   'rating': '4.02 avg rating — 7,841 ratings'},
#  {'rank': '84',
#   'title': 'Delirium (Delirium, #1)',
#   'author': 'Lauren Oliver',
#   'score': 'score: 1,366',
#   'votes': '15 people voted',
#   'rating': '3.98 avg rating — 392,304 ratings'},
#  {'rank': '85',
#   'title': 'Dreamsnake',
#   'author': 'Vonda N. McIntyre',
#   'score': 'score: 1,324',
#   'votes': '18 people voted',
#   'rating': '3.86 avg rating — 8,406 ratings'},
#  {'rank': '86',
#   'title': 'Women of Wonder: Science-Fiction Stories by Women about Women',
#   'author': 'Pamela Sargent',
#   'score': 'score: 1,297',
#   'votes': '16 people voted',
#   'rating': 'really liked it 4.00 avg rating — 272 ratings'},
#  {'rank': '87',
#   'title': 'All Systems Red (The Murderbot Diaries, #1)',
#   'author': 'Martha Wells',
#   'score': 'score: 1,296',
#   'votes': '14 people voted',
#   'rating': '4.15 avg rating — 35,094 ratings'},
#  {'rank': '88',
#   'title': "Trading in Danger (Vatta's War, #1)",
#   'author': 'Elizabeth Moon',
#   'score': 'score: 1,286',
#   'votes': '16 people voted',
#   'rating': '3.98 avg rating — 11,163 ratings'},
#  {'rank': '89',
#   'title': 'Invader (Foreigner, #2)',
#   'author': 'C.J. Cherryh',
#   'score': 'score: 1,276',
#   'votes': '17 people voted',
#   'rating': '4.17 avg rating — 4,058 ratings'},
#  {'rank': '89',
#   'title': 'Woman on the Edge of Time',
#   'author': 'Marge Piercy',
#   'score': 'score: 1,276',
#   'votes': '15 people voted',
#   'rating': '3.95 avg rating — 12,600 ratings'},
#  {'rank': '91',
#   'title': 'China Mountain Zhang',
#   'author': 'Maureen F. McHugh',
#   'score': 'score: 1,253',
#   'votes': '18 people voted',
#   'rating': '3.94 avg rating — 3,453 ratings'},
#  {'rank': '92',
#   'title': 'Stardoc (Stardoc, #1)',
#   'author': 'S.L. Viehl',
#   'score': 'score: 1,230',
#   'votes': '16 people voted',
#   'rating': '3.80 avg rating — 3,632 ratings'},
#  {'rank': '93',
#   'title': 'MaddAddam (MaddAddam, #3)',
#   'author': 'Margaret Atwood',
#   'score': 'score: 1,212',
#   'votes': '13 people voted',
#   'rating': 'really liked it 4.00 avg rating — 52,204 ratings'},
#  {'rank': '94',
#   'title': "Valor's Choice (Confederation, #1)",
#   'author': 'Tanya Huff',
#   'score': 'score: 1,165',
#   'votes': '16 people voted',
#   'rating': '3.98 avg rating — 6,899 ratings'},
#  {'rank': '95',
#   'title': 'Bellwether',
#   'author': 'Connie Willis',
#   'score': 'score: 1,142',
#   'votes': '13 people voted',
#   'rating': '3.93 avg rating — 10,069 ratings'},
#  {'rank': '96',
#   'title': 'This Alien Shore',
#   'author': 'C.S. Friedman',
#   'score': 'score: 1,130',
#   'votes': '15 people voted',
#   'rating': '4.04 avg rating — 3,262 ratings'},
#  {'rank': '97',
#   'title': 'Primary Inversion (Saga of the Skolian Empire, #1)',
#   'author': 'Catherine Asaro',
#   'score': 'score: 1,119',
#   'votes': '15 people voted',
#   'rating': '3.74 avg rating — 3,686 ratings'},
#  {'rank': '98',
#   'title': 'Scarlet (The Lunar Chronicles, #2)',
#   'author': 'Marissa Meyer',
#   'score': 'score: 1,115',
#   'votes': '12 people voted',
#   'rating': '4.29 avg rating — 265,319 ratings'},
#  {'rank': '99',
#   'title': 'Probability Moon (Probability, #1)',
#   'author': 'Nancy Kress',
#   'score': 'score: 1,107',
#   'votes': '15 people voted',
#   'rating': '3.61 avg rating — 1,292 ratings'},
#  {'rank': '100',
#   'title': 'The House of the Scorpion (Matteo Alacran, #1)',
#   'author': 'Nancy Farmer',
#   'score': 'score: 1,083',
#   'votes': '12 people voted',
#   'rating': '4.10 avg rating — 72,377 ratings'}]

# %%
df = pd.DataFrame(rows)
df
# Out:
#                          author rank  \
# 0               Margaret Atwood    1
# 1               Suzanne Collins    2
# 2   Mary Wollstonecraft Shelley    3
# 3             Madeleine L'Engle    4
# 4             Ursula K. Le Guin    5
# 5                 Veronica Roth    6
# 6               Suzanne Collins    7
# 7                    Lois Lowry    8
# 8             Octavia E. Butler    9
# 9             Ursula K. Le Guin   10
# 10              Margaret Atwood   11
# 11              Suzanne Collins   12
# 12           Audrey Niffenegger   13
# 13                Connie Willis   14
# 14            Ursula K. Le Guin   15
# 15                   Ann Leckie   16
# 16         Lois McMaster Bujold   17
# 17                Connie Willis   18
# 18           Mary Doria Russell   19
# 19               Anne McCaffrey   20
# 20            Octavia E. Butler   21
# 21         Lois McMaster Bujold   22
# 22         Lois McMaster Bujold   23
# 23              Stephenie Meyer   24
# 24                Veronica Roth   25
# 25         Lois McMaster Bujold   26
# 26                   P.D. James   27
# 27                 G.S. Jennsen   28
# 28              Margaret Atwood   29
# 29               Anne McCaffrey   30
# ..                          ...  ...
# 70        Marion Zimmer Bradley   71
# 71                 Hayley Stone   72
# 72                 G.S. Jennsen   73
# 73         Lois McMaster Bujold   74
# 74            Octavia E. Butler   75
# 75            Ursula K. Le Guin   76
# 76               Elizabeth Moon   77
# 77            Ursula K. Le Guin   78
# 78                  Ann Aguirre   79
# 79              Nicola Griffith   80
# 80                   Beth Revis   81
# 81                 C.J. Cherryh   82
# 82                  Mya Robarts   83
# 83                Lauren Oliver   84
# 84            Vonda N. McIntyre   85
# 85               Pamela Sargent   86
# 86                 Martha Wells   87
# 87               Elizabeth Moon   88
# 88                 C.J. Cherryh   89
# 89                 Marge Piercy   89
# 90            Maureen F. McHugh   91
# 91                   S.L. Viehl   92
# 92              Margaret Atwood   93
# 93                   Tanya Huff   94
# 94                Connie Willis   95
# 95                C.S. Friedman   96
# 96              Catherine Asaro   97
# 97                Marissa Meyer   98
# 98                  Nancy Kress   99
# 99                 Nancy Farmer  100
#
#                                               rating          score  \
# 0                4.09 avg rating — 1,102,749 ratings  score: 30,733
# 1                4.33 avg rating — 5,742,283 ratings  score: 28,553
# 2                3.78 avg rating — 1,023,563 ratings  score: 21,909
# 3                  4.01 avg rating — 903,541 ratings  score: 18,720
# 4                   4.06 avg rating — 98,810 ratings  score: 17,920
# 5                4.21 avg rating — 2,603,019 ratings  score: 13,326
# 6                4.29 avg rating — 2,200,866 ratings  score: 12,749
# 7                4.12 avg rating — 1,535,313 ratings  score: 12,399
# 8                   4.23 avg rating — 72,354 ratings  score: 11,070
# 9                   4.21 avg rating — 71,652 ratings  score: 10,731
# 10                 4.01 avg rating — 197,821 ratings  score: 10,117
# 11               4.03 avg rating — 2,072,116 ratings   score: 9,807
# 12               3.96 avg rating — 1,446,821 ratings   score: 9,193
# 13                  4.03 avg rating — 43,253 ratings   score: 8,935
# 14                  4.11 avg rating — 44,001 ratings   score: 7,775
# 15                  3.98 avg rating — 66,220 ratings   score: 7,336
# 16                  4.11 avg rating — 25,885 ratings   score: 7,017
# 17                  4.13 avg rating — 29,644 ratings   score: 6,890
# 18                  4.17 avg rating — 52,755 ratings   score: 6,873
# 19                 4.10 avg rating — 116,164 ratings   score: 6,802
# 20                  4.16 avg rating — 42,254 ratings   score: 6,653
# 21                  4.29 avg rating — 20,959 ratings   score: 6,087
# 22                  4.31 avg rating — 22,112 ratings   score: 5,623
# 23                 3.84 avg rating — 829,025 ratings   score: 5,274
# 24               4.05 avg rating — 1,045,881 ratings   score: 4,899
# 25                  4.45 avg rating — 13,950 ratings   score: 4,682
# 26                  3.68 avg rating — 36,107 ratings   score: 4,484
# 27                   3.91 avg rating — 2,146 ratings   score: 4,394
# 28                  4.06 avg rating — 92,237 ratings   score: 4,343
# 29                  4.09 avg rating — 17,775 ratings   score: 4,235
# ..                                               ...            ...
# 70                   3.88 avg rating — 5,952 ratings   score: 1,748
# 71                     3.79 avg rating — 248 ratings   score: 1,698
# 72                   4.22 avg rating — 1,042 ratings   score: 1,684
# 73                  4.06 avg rating — 11,943 ratings   score: 1,683
# 74                   4.33 avg rating — 3,946 ratings   score: 1,659
# 75                   4.04 avg rating — 4,042 ratings   score: 1,572
# 76                   4.06 avg rating — 3,628 ratings   score: 1,547
# 77                  3.95 avg rating — 12,905 ratings   score: 1,510
# 78                  3.73 avg rating — 12,662 ratings   score: 1,497
# 79                   3.86 avg rating — 3,715 ratings   score: 1,477
# 80                 3.77 avg rating — 107,422 ratings   score: 1,435
# 81                   4.19 avg rating — 3,610 ratings   score: 1,392
# 82                   4.02 avg rating — 7,841 ratings   score: 1,380
# 83                 3.98 avg rating — 392,304 ratings   score: 1,366
# 84                   3.86 avg rating — 8,406 ratings   score: 1,324
# 85     really liked it 4.00 avg rating — 272 ratings   score: 1,297
# 86                  4.15 avg rating — 35,094 ratings   score: 1,296
# 87                  3.98 avg rating — 11,163 ratings   score: 1,286
# 88                   4.17 avg rating — 4,058 ratings   score: 1,276
# 89                  3.95 avg rating — 12,600 ratings   score: 1,276
# 90                   3.94 avg rating — 3,453 ratings   score: 1,253
# 91                   3.80 avg rating — 3,632 ratings   score: 1,230
# 92  really liked it 4.00 avg rating — 52,204 ratings   score: 1,212
# 93                   3.98 avg rating — 6,899 ratings   score: 1,165
# 94                  3.93 avg rating — 10,069 ratings   score: 1,142
# 95                   4.04 avg rating — 3,262 ratings   score: 1,130
# 96                   3.74 avg rating — 3,686 ratings   score: 1,119
# 97                 4.29 avg rating — 265,319 ratings   score: 1,115
# 98                   3.61 avg rating — 1,292 ratings   score: 1,107
# 99                  4.10 avg rating — 72,377 ratings   score: 1,083
#
#                                                 title             votes
# 0                                 The Handmaid's Tale  314 people voted
# 1             The Hunger Games (The Hunger Games, #1)  292 people voted
# 2                                        Frankenstein  224 people voted
# 3                A Wrinkle in Time (Time Quintet, #1)  196 people voted
# 4        The Left Hand of Darkness (Hainish Cycle #4)  184 people voted
# 5                           Divergent (Divergent, #1)  138 people voted
# 6                Catching Fire (The Hunger Games, #2)  133 people voted
# 7                           The Giver (The Giver, #1)  129 people voted
# 8                                             Kindred  116 people voted
# 9                 The Dispossessed (Hainish Cycle #6)  112 people voted
# 10                     Oryx and Crake (MaddAddam, #1)  107 people voted
# 11                  Mockingjay (The Hunger Games, #3)  104 people voted
# 12                           The Time Traveler's Wife   98 people voted
# 13             Doomsday Book (Oxford Time Travel, #1)   96 people voted
# 14                                The Lathe of Heaven   84 people voted
# 15              Ancillary Justice (Imperial Radch #1)   81 people voted
# 16            Shards of Honour  (Vorkosigan Saga, #1)   75 people voted
# 17  To Say Nothing of the Dog (Oxford Time Travel,...   74 people voted
# 18                      The Sparrow (The Sparrow, #1)   72 people voted
# 19            Dragonflight (Dragonriders of Pern, #1)   74 people voted
# 20               Parable of the Sower (Earthseed, #1)   71 people voted
# 21     The Warrior's Apprentice (Vorkosigan Saga, #2)   65 people voted
# 22                     Barrayar (Vorkosigan Saga, #7)   60 people voted
# 23                            The Host (The Host, #1)   56 people voted
# 24                          Insurgent (Divergent, #2)   54 people voted
# 25                      Memory (Vorkosigan Saga, #10)   51 people voted
# 26                                The Children of Men   49 people voted
# 27  Starshine: Aurora Rising Book One (Aurora Rhap...   45 people voted
# 28             The Year of the Flood  (MaddAddam, #2)   47 people voted
# 29                Crystal Singer (Crystal Singer, #1)   47 people voted
# ..                                                ...               ...
# 70                                  Darkover Landfall   21 people voted
# 71                    Machinations (Machinations, #1)   17 people voted
# 72                      Vertigo (Aurora Rhapsody, #2)   18 people voted
# 73                    CryoBurn (Vorkosigan Saga, #14)   24 people voted
# 74              Seed to Harvest (Patternmaster, #1-4)   20 people voted
# 75                         The Wind's Twelve Quarters   19 people voted
# 76                                 Remnant Population   20 people voted
# 77                       The Word for World is Forest   20 people voted
# 78                       Grimspace (Sirantha Jax, #1)   17 people voted
# 79                                           Ammonite   20 people voted
# 80      Across the Universe (Across the Universe, #1)   16 people voted
# 81                          Inheritor (Foreigner, #3)   18 people voted
# 82                                         The V Girl   15 people voted
# 83                            Delirium (Delirium, #1)   15 people voted
# 84                                         Dreamsnake   18 people voted
# 85  Women of Wonder: Science-Fiction Stories by Wo...   16 people voted
# 86        All Systems Red (The Murderbot Diaries, #1)   14 people voted
# 87                Trading in Danger (Vatta's War, #1)   16 people voted
# 88                            Invader (Foreigner, #2)   17 people voted
# 89                          Woman on the Edge of Time   15 people voted
# 90                               China Mountain Zhang   18 people voted
# 91                              Stardoc (Stardoc, #1)   16 people voted
# 92                          MaddAddam (MaddAddam, #3)   13 people voted
# 93                 Valor's Choice (Confederation, #1)   16 people voted
# 94                                         Bellwether   13 people voted
# 95                                   This Alien Shore   15 people voted
# 96  Primary Inversion (Saga of the Skolian Empire,...   15 people voted
# 97                 Scarlet (The Lunar Chronicles, #2)   12 people voted
# 98                 Probability Moon (Probability, #1)   15 people voted
# 99     The House of the Scorpion (Matteo Alacran, #1)   12 people voted
#
# [100 rows x 6 columns]

# %%
df.to_csv("goodreads.csv", index=False)
